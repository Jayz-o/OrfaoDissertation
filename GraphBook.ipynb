# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# create data
x = [0,5, 10, 20, 30]
ASUS_APCER = [0.090339233,	0.091076696,	0.102876106,	0.116642085, 0.117010816]
ASUS_BPCER = [0.010250124,	0.005027357,	0.006679457,	0.001936332,	0.003588432
]
ASUS_ACER = [0.050294679,	0.048052027	,0.054777782,	0.059289208	,0.060299624
]
IP7P_APCER = [0.000188111,	0.000376223	,0.000564334,	0.000376223	,0.00065839
]
IP7P_BPCER = [0.028103461	,0.014478079	,0.015082072	,0.023040574	,0.024888084
]
IP7P_ACER = [0.014145786	,0.007427151	,0.007823203	,0.011708398	,0.012773237
]
IPP2017_APCER = [0.07915947,	0.110535406	,0.10880829	,0.111686816	,0.133659566
]
IPP2017_BPCER = [0.008811199	,0.002504796	,0.002060684,	0.022365523	,0.002646913
]
IPP2017_ACER = [0.043985335	,0.056520101,0.055434487,0.067026169,	0.068153239
]
SGS8_APCER = [0,	0	,0	,0.000185185	,0
]
SGS8_BPCER = [0.073704967,	0.045050807,	0.029009451,	0.019292262,	0.019096852
]
SGS8_ACER = [0.036852483	,0.022525403,	0.014504725,	0.009738723,	0.009548426
]

# plot lines
plt.plot(x, ASUS_APCER, label = "ASUS APCER", linestyle="--")
plt.plot(x, IP7P_APCER, label = "IP7P APCER" , linestyle="--")
plt.plot(x, IPP2017_APCER, label = "IPP2017" , linestyle="--")
plt.plot(x, SGS8_APCER, label = "SGS8" , linestyle="--")
plt.legend()
plt.show()

# %%
# create data
x = [0,5, 10, 20, 30]
ASUS_APCER = [0.090339233,	0.091076696,	0.102876106,	0.116642085, 0.117010816]
ASUS_BPCER = [0.010250124,	0.005027357,	0.006679457,	0.001936332,	0.003588432
]
ASUS_ACER = [0.050294679,	0.048052027	,0.054777782,	0.059289208	,0.060299624
]
IP7P_APCER = [0.000188111,	0.000376223	,0.000564334,	0.000376223	,0.00065839
]
IP7P_BPCER = [0.028103461	,0.014478079	,0.015082072	,0.023040574	,0.024888084
]
IP7P_ACER = [0.014145786	,0.007427151	,0.007823203	,0.011708398	,0.012773237
]
IPP2017_APCER = [0.07915947,	0.110535406	,0.10880829	,0.111686816	,0.133659566
]
IPP2017_BPCER = [0.008811199	,0.002504796	,0.002060684,	0.022365523	,0.002646913
]
IPP2017_ACER = [0.043985335	,0.056520101,0.055434487,0.067026169,	0.068153239
]
SGS8_APCER = [0,	0	,0	,0.000185185	,0
]
SGS8_BPCER = [0.073704967,	0.045050807,	0.029009451,	0.019292262,	0.019096852
]
SGS8_ACER = [0.036852483	,0.022525403,	0.014504725,	0.009738723,	0.009548426
]
ASUS = [[i * 100 for i in ASUS_APCER], [j * 100 for j in ASUS_BPCER], [k * 100 for k in ASUS_ACER]]
IP7P = [[i * 100 for i in IP7P_APCER], [i * 100 for i in IP7P_BPCER], [i * 100 for i in IP7P_ACER]]
IPP2017 = [[i * 100 for i in IPP2017_APCER], [i * 100 for i in IPP2017_BPCER], [i * 100 for i in IPP2017_ACER]]
SGS8 = [[i * 100 for i in SGS8_APCER], [i * 100 for i in SGS8_BPCER], [i * 100 for i in SGS8_ACER]]

DEVICES = [ASUS, IP7P, IPP2017, SGS8]
device_names = ["ASUS", "IP7P", "IPP2017", "SGS8" ]
metric_names = ["APCER", "BPCER", "ACER"]
fig, ax = plt.subplots()
colors = ['tab:blue', 'tab:red', 'tab:green',]# "tab:purple" ]
styles = ['--', '-.', ':', '-']

for device_index, col in enumerate(styles):
    for metric_index, sty in enumerate(colors):
        ax.plot(x, DEVICES[device_index][metric_index] , c=colors[metric_index], ls=styles[device_index])

for device_index, col in enumerate(colors):
    ax.plot(np.NaN, np.NaN, c=colors[device_index], label=metric_names[device_index])

ax2 = ax.twinx()
for metric_index, sty in enumerate(styles):
    ax2.plot(np.NaN, np.NaN, ls=styles[metric_index],
             label=device_names[metric_index], c='black')
ax2.get_yaxis().set_visible(False)

ax.legend(loc=1)
ax2.legend(loc=2)
# ax.set_title('The APCER, BPCER and ACER of each SiW protocol 2 spoof medium')
ax.set_ylabel('Metric (%)')
ax.set_xlabel('Augmentation (%)')
plt.savefig("protocol_2_individual_1.pdf", dpi=1000)
plt.show()

# %%
# create data
x = [0,5, 10, 20, 30]

P2_Apcer =	[0.042421704,	0.050497081,	0.053062183,	0.057222577,	0.062832193]
P2_BPCER	=[0.030217438,	0.01676526,	0.013207916,	0.016658673,	0.01255507]
P2_Acer	=[0.036319571	,0.03363117	,0.033135049,0.036940625	,0.037693632]

P3_Apcer=[	0.182129893	,0.160947027,	0.162802704	,0.175089873,	0.171754002]
P3_BPCER=[	0.007336744	,0.005133944,	0.004192425	,0.004547715,	0.005524764]
P3_Acer	=[.094733319	,0.083040486,	0.083497565	,0.089818794,	0.088639383]
P2 = [[i * 100 for i in P2_Apcer], [i * 100 for i in P2_BPCER], [i * 100 for i in P2_Acer]]
P3 = [[i * 100 for i in P3_Apcer], [i * 100 for i in P3_BPCER], [i * 100 for i in P3_Acer]]

Protocols = [P2, P3]
Protocols_names = ["P2", "P3" ]
metric_names = ["APCER", "BPCER", "ACER"]
fig, ax = plt.subplots()
colors = ['tab:blue', 'tab:red', 'tab:green',]# "tab:purple" ]
styles = ['--', '-']

for protocol_index, col in enumerate(styles):
    for metric_index, sty in enumerate(colors):
        ax.plot(x, Protocols[protocol_index][metric_index] , c=colors[metric_index], ls=styles[protocol_index])

for device_index, col in enumerate(colors):
    ax.plot(np.NaN, np.NaN, c=colors[device_index], label=metric_names[device_index])

ax2 = ax.twinx()
for metric_index, sty in enumerate(styles):
    ax2.plot(np.NaN, np.NaN, ls=styles[metric_index],
             label=Protocols_names[metric_index], c='black')
ax2.get_yaxis().set_visible(False)

ax.legend(loc=1)
ax2.legend(loc=2)
# ax.set_title('The APCER, BPCER and ACER of each SiW protocol 2 spoof medium')
ax.set_ylabel('Metric (%)')
ax.set_xlabel('Augmentation (%)')
plt.savefig("siw_combined_protocols.pdf", dpi=1000)
plt.show()

# %%
# create data
x = [0,5, 10, 20, 30]

UP_Apcer	=[0.061108587,	0.043692261,	0.058534,	0.101090413,	0.112978949]
UP_BPCER=[	0.012985859	,0.008296028	,0.006199815	,0.007425567	,0.009432957]
UP_Acer=[	0.037047223	,0.025994144	,0.032366907	,0.05425799,	0.061205953]

UR_Apcer	= [0.3031512	,0.278201792,	0.267071408	,0.249089332	,0.230529055]
UR_BPCER	= [0.001687629	,0.001971861,	0.002185035	,0.001669864	,0.001616571]
UR_Acer	= [0.152419414	,0.140086827,	0.134628222,	0.125379598,	0.116072813]

UP = [[i * 100 for i in UP_Apcer], [i * 100 for i in UP_BPCER], [i * 100 for i in UP_Acer]]
UR = [[i * 100 for i in UR_Apcer], [i * 100 for i in UR_BPCER], [i * 100 for i in UR_Acer]]

Protocols = [UP, UR]
Protocols_names = ["Photo", "Video-Replay" ]
metric_names = ["APCER", "BPCER", "ACER"]
fig, ax = plt.subplots()
colors = ['tab:blue', 'tab:red', 'tab:green',]# "tab:purple" ]
styles = ['--', '-']

for protocol_index, col in enumerate(styles):
    for metric_index, sty in enumerate(colors):
        ax.plot(x, Protocols[protocol_index][metric_index] , c=colors[metric_index], ls=styles[protocol_index])

for device_index, col in enumerate(colors):
    ax.plot(np.NaN, np.NaN, c=colors[device_index], label=metric_names[device_index])

ax2 = ax.twinx()
for metric_index, sty in enumerate(styles):
    ax2.plot(np.NaN, np.NaN, ls=styles[metric_index],
             label=Protocols_names[metric_index], c='black')
ax2.get_yaxis().set_visible(False)

ax.legend(loc=1)
ax2.legend(loc=2)
# ax.set_title('The APCER, BPCER and ACER of each SiW protocol 2 spoof medium')
ax.set_ylabel('Metric (%)')
ax.set_xlabel('Augmentation (%)')
plt.savefig("siw_protocol_3_individual.pdf", dpi=1000)
plt.show()

# %%
labels = [str(i) for i in range(1, 8)]

kf_baseline = [97.73, 95.90, 97.21, 96.87, 96.57, 96.98, 96.66]
ef_baseline = [97.73, 96.52, 98.05, 97.73, 96.97, 97.48, 97.42]
kf_augmented = [98.86, 96.71, 98.06, 97.90, 97.93, 97.89, 97.55]
ef_augmented = [99.50, 97.51, 98.82, 98.26, 98.01, 98.43, 98.02]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars
fig, ax = plt.subplots(figsize=(13, 9), dpi=1200)

rects1 = ax.barh(x + 0.3, kf_baseline, width, label='KF Baseline')
rects2 = ax.barh(x + 0.1, kf_augmented, width, label='KF Augmented')
rects3 = ax.barh(x - 0.1, ef_baseline, width, label='EF Baseline')
rects4 = ax.barh(x - 0.3, ef_augmented, width, label='EF Augmented')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('AUC Percentage')
ax.set_ylabel('CASIA-FA test protocol')
ax.set_title('The AUC for each CASIA-FA test protocol')
# ax.set_yticks(labels,)
ax.set_yticks(x)
ax.set_yticklabels(labels)
ax.legend(bbox_to_anchor=(0.565, -0.1))
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
ax.bar_label(rects4, padding=3)
fig.tight_layout()
plt.show()
# plt.savefig("test.pdf")
